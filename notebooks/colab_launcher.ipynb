# %% [markdown]
# # voice-service Colab launcher
#
# Set `GITHUB_REPO_URL`, run the cells, then use the printed public API URL from review-drama.

# %%
GITHUB_REPO_URL = "https://github.com/YOUR_USER/voice-service.git"
PROJECT_DIR = "/content/voice-service"
API_KEY = ""  # optional

# %%
# !rm -rf "$PROJECT_DIR"
# !git clone "$GITHUB_REPO_URL" "$PROJECT_DIR"
# %cd "$PROJECT_DIR"
# !pip install -U -r requirements.txt

# %%
import os
if API_KEY:
    os.environ["VOICE_SERVICE_API_KEY"] = API_KEY

# Optional model download config:
# os.environ["HF_MODEL_REPO"] = "owner/repo"
# os.environ["HF_MODEL_FILES"] = "model.safetensors,config.json"

# !python scripts/start_colab.py --mount-drive --drive-root /content/drive/MyDrive/voice-service --tunnel cloudflared
